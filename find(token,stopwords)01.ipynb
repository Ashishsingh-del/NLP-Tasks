# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashishsingh-del/NLP-Tasks/blob/main/find(token%2Cstopwords)01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer ,WordNetLemmatizer
from nltk import pos_tag

nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')

text=input("Enter the text")

#Tokenization
tokens=word_tokenize(text)

#stopword removal
stop_words =set(stopwords.words('english'))
print("stop words",stop_words)
s=0
filtered=[]
for w in tokens:
    s=s+1
    if w.lower() not in stop_words:
        filtered.append(w)

 #stemming
stemmer= PorterStemmer()
stems=[]
ss=0
for word in filtered:
    ss=ss+1
    stemmed_word=stemmer.stem(word)
    stems.append(stemmed_word)

#Lemmatization
lemmatizer = WordNetLemmatizer()
lemmas=[]
l=0
for word in filtered:
    l=1+1
    lemmas.append(lemmatizer.lemmatize(word))

#POS tagging
    pos_tags=pos_tag(filtered)
    print("Total Number of Tokens",s)
    print("Tokens:",tokens)
    print("Total Number of Stems",ss)
    print("Filtered:",filtered)
    print("Stems:",stems)
    print("Total Number of Lema",l)
    print("Lemmas:",lemmas)
    print("POS Tags:",pos_tags)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# Enter the textindia is a beautiful country.
# ...
